# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
obj = pd.read_csv('data.csv')
obj
# Out:
#      Time (s) Run #1  Light Intensity (%) Run #1  Angle (rad) Run #1  \
# 0               0.00                         0.6                 0.0
# 1               0.05                         0.6                 0.0
# 2               0.10                         0.6                 0.0
# 3               0.15                         0.6                 0.0
# 4               0.20                         0.6                 0.0
# ..               ...                         ...                 ...
# 614              NaN                         NaN                 NaN
# 615              NaN                         NaN                 NaN
# 616              NaN                         NaN                 NaN
# 617              NaN                         NaN                 NaN
# 618              NaN                         NaN                 NaN
#
#      Angular Velocity (rad/s) Run #1  Angular Acceleration (rad/s²) Run #1  \
# 0                                NaN                                   NaN
# 1                                0.0                                   NaN
# 2                                0.0                                   0.0
# 3                                0.0                                   0.0
# 4                                0.0                                   0.0
# ..                               ...                                   ...
# 614                              NaN                                   NaN
# 615                              NaN                                   NaN
# 616                              NaN                                   NaN
# 617                              NaN                                   NaN
# 618                              NaN                                   NaN
#
#      Position (m) Run #1  Velocity (m/s) Run #1  Acceleration (m/s²) Run #1  \
# 0                    0.0                    NaN                         NaN
# 1                    0.0                    0.0                         NaN
# 2                    0.0                    0.0                         0.0
# 3                    0.0                    0.0                         0.0
# 4                    0.0                    0.0                         0.0
# ..                   ...                    ...                         ...
# 614                  NaN                    NaN                         NaN
# 615                  NaN                    NaN                         NaN
# 616                  NaN                    NaN                         NaN
# 617                  NaN                    NaN                         NaN
# 618                  NaN                    NaN                         NaN
#
#      Counts Run #1  Time (s) Run #2  ...  Counts Run #2  Time (s) Run #3  \
# 0              0.0             0.00  ...            0.0             0.00
# 1              0.0             0.05  ...            0.0             0.05
# 2              0.0             0.10  ...            0.0             0.10
# 3              0.0             0.15  ...            0.0             0.15
# 4              0.0             0.20  ...            0.0             0.20
# ..             ...              ...  ...            ...              ...
# 614            NaN              NaN  ...            NaN            30.70
# 615            NaN              NaN  ...            NaN            30.75
# 616            NaN              NaN  ...            NaN            30.80
# 617            NaN              NaN  ...            NaN            30.85
# 618            NaN              NaN  ...            NaN            30.90
#
#      Light Intensity (%) Run #3  Angle (rad) Run #3  \
# 0                           0.0               0.000
# 1                           0.0               0.000
# 2                           0.0               0.000
# 3                           0.0               0.000
# 4                           0.0               0.000
# ..                          ...                 ...
# 614                         0.0              85.783
# 615                         0.0              85.783
# 616                         0.0              85.783
# 617                         0.0              85.783
# 618                         0.0              85.783
#
#      Angular Velocity (rad/s) Run #3  Angular Acceleration (rad/s²) Run #3  \
# 0                                NaN                                   NaN
# 1                                0.0                                   NaN
# 2                                0.0                                   0.0
# 3                                0.0                                   0.0
# 4                                0.0                                   0.0
# ..                               ...                                   ...
# 614                              0.0                                   0.0
# 615                              0.0                                   0.0
# 616                              0.0                                   NaN
# 617                              0.0                                   NaN
# 618                              NaN                                   NaN
#
#      Position (m) Run #3  Velocity (m/s) Run #3  Acceleration (m/s²) Run #3  \
# 0                 0.0000                    NaN                         NaN
# 1                 0.0000                    0.0                         NaN
# 2                 0.0000                    0.0                         0.0
# 3                 0.0000                    0.0                         0.0
# 4                 0.0000                    0.0                         0.0
# ..                   ...                    ...                         ...
# 614               2.0479                    0.0                         0.0
# 615               2.0479                    0.0                         0.0
# 616               2.0479                    0.0                         NaN
# 617               2.0479                    0.0                         NaN
# 618               2.0479                    NaN                         NaN
#
#      Counts Run #3
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ..             ...
# 614           4915
# 615           4915
# 616           4915
# 617           4915
# 618           4915
#
# [619 rows x 27 columns]

# %%
inten = "Light Intensity".split()
ang = "Angle (rad)".split()
dropp = []
for elem in obj.columns:
    elem_lst = elem.split()
    if elem_lst[:2] != inten and elem_lst[:2] != ang:
        dropp.append(elem)
obj = obj.drop(dropp, axis=1)
obj
# Out:
#      Light Intensity (%) Run #1  Angle (rad) Run #1  \
# 0                           0.6                 0.0
# 1                           0.6                 0.0
# 2                           0.6                 0.0
# 3                           0.6                 0.0
# 4                           0.6                 0.0
# ..                          ...                 ...
# 614                         NaN                 NaN
# 615                         NaN                 NaN
# 616                         NaN                 NaN
# 617                         NaN                 NaN
# 618                         NaN                 NaN
#
#      Light Intensity (%) Run #2  Angle (rad) Run #2  \
# 0                           0.2                 0.0
# 1                           0.2                 0.0
# 2                           0.2                 0.0
# 3                           0.2                 0.0
# 4                           0.2                 0.0
# ..                          ...                 ...
# 614                         NaN                 NaN
# 615                         NaN                 NaN
# 616                         NaN                 NaN
# 617                         NaN                 NaN
# 618                         NaN                 NaN
#
#      Light Intensity (%) Run #3  Angle (rad) Run #3
# 0                           0.0               0.000
# 1                           0.0               0.000
# 2                           0.0               0.000
# 3                           0.0               0.000
# 4                           0.0               0.000
# ..                          ...                 ...
# 614                         0.0              85.783
# 615                         0.0              85.783
# 616                         0.0              85.783
# 617                         0.0              85.783
# 618                         0.0              85.783
#
# [619 rows x 6 columns]

# %%
y = obj['Light Intensity (%) Run #1'].values
x = obj["Angle (rad) Run #1"].values
plt.plot(x,y,"o")
plt.title("The Sodium Spectrum")
plt.xlabel("Angle (rad)")
plt.ylabel("Light Intensity Percent")
# Out:
# Text(0, 0.5, 'Angle (rad)')

# %%
y = obj['Light Intensity (%) Run #1'].values
x = obj["Angle (rad) Run #1"].values
plt.plot(x,y,"o")
plt.title("The Sodium Spectrum")
plt.xlabel("Light Intensity Percent")
plt.ylabel("Angle (rad)")
